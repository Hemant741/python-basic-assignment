# %% [markdown]
# ## 1. Make a class called Thing with no contents and print it. Then, create an object called example from this class and also print it. Are the printed values the same or different?
#
# Ans:-here's an implementation of the Thing class in Python:
#
# class Thing:
#
#     pass
#
# print(Thing())
#
# example = Thing()
#
# print(example)
#
#
# When this code is executed, the output will be:
#
# <__main__.Thing object at 0x7f6fa3d3e2e0>
#
# <__main__.Thing object at 0x7f6fa3d3e3a0>

# %% [markdown]
# ## 2. Create a new class called Thing2 and add the value 'abc' to the letters class attribute. Letters should be printed.
#
# Ans:-Here's an implementation of the Thing2 class in Python, which has a class attribute called letters with the value 'abc':
#
# class Thing2:
#
#     letters = 'abc'
#
# print(Thing2.letters)
#
#
# When this code is executed, the output will be:
#
#
# abc

# %% [markdown]
# ## 3. Make yet another class called, of course, Thing3. This time, assign the value 'xyz' to an instance (object) attribute called letters. Print letters. Do you need to make an object from the class to do this?
#
# Ans:-Here's an implementation of the Thing3 class in Python, which has an instance attribute called letters with the value 'xyz':
#
# class Thing3:
#
#     def __init__(self):
#
#         self.letters = 'xyz'
#
# example = Thing3()
#
# print(example.letters)
#
#
# When this code is executed, the output will be:
#
# xyz

# %% [markdown]
# ## 4. Create an Element class with the instance attributes name, symbol, and number. Create a class object with the values 'Hydrogen,' 'H,' and 1.
#
# Ans:-Here's an implementation of the Element class in Python, with instance attributes name, symbol, and number:
#
# class Element:
#
#     def __init__(self, name, symbol, number):
#
#         self.name = name
#
#         self.symbol = symbol
#
#         self.number = number
#
# hydrogen = Element('Hydrogen', 'H', 1)
#
#
# In this code, we create an instance of the Element class called hydrogen, and pass in the values 'Hydrogen', 'H', and 1 as arguments to the __init__() method of the class. These values are then assigned to the instance attributes name, symbol, and number, respectively, for the hydrogen object.

# %% [markdown]
# ## 5. Make a dictionary with these keys and values: 'name': 'Hydrogen', 'symbol': 'H', 'number': 1. Then, create an object called hydrogen from class Element using this dictionary.
#
# Ans:-Here's an implementation of the steps in Python:
#
# class Element:
#
#     def __init__(self, name, symbol, number):
#
#         self.name = name
#
#         self.symbol = symbol
#
#         self.number = number
#
# element_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
#
# hydrogen = Element(**element_dict)

# %% [markdown]
# ## 6. For the Element class, define a method called dump() that prints the values of the object’s attributes (name, symbol, and number). Create the hydrogen object from this new definition and use dump() to print its attributes.
#
# Ans:-Here's an updated implementation of the Element class in Python, which includes a dump() method to print the values of its instance attributes:
#
# class Element:
#
#     def __init__(self, name, symbol, number):
#
#         self.name = name
#
#         self.symbol = symbol
#
#         self.number = number
#
#     def dump(self):
#
#         print(f'Name: {self.name}')
#
#         print(f'Symbol: {self.symbol}')
#
#         print(f'Number: {self.number}')
#
# element_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
#
# hydrogen = Element(**element_dict)
#
# hydrogen.dump()
#
#
#  This will output:
#
#  Name: Hydrogen
#
# Symbol: H
#
# Number: 1

# %% [markdown]
# ## 7. Call print(hydrogen). In the definition of Element, change the name of method dump to __str__, create a new hydrogen object, and call print(hydrogen) again.
#
# Ans:-Here's an updated implementation of the Element class in Python, with the dump() method renamed to __str__():
#
# class Element:
#
#     def __init__(self, name, symbol, number):
#
#         self.name = name
#
#         self.symbol = symbol
#
#         self.number = number
#
#     def __str__(self):
#
#         return f'Name: {self.name}\nSymbol: {self.symbol}\nNumber: {self.number}'
#
# element_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
#
# hydrogen = Element(**element_dict)
#
# print(hydrogen)
#
# This will output:
#
# Name: Hydrogen
#
# Symbol: H
#
# Number: 1

# %% [markdown]
# ## 8. Modify Element to make the attributes name, symbol, and number private. Define a getter property for each to return its value.
#
# Ans:-Here's an updated implementation of the Element class in Python, with the name, symbol, and number instance attributes made private and getter methods defined for each attribute:
#
#
# class Element:
#
#     def __init__(self, name, symbol, number):
#
#         self.__name = name
#
#         self.__symbol = symbol
#
#         self.__number = number
#
#     def get_name(self):
#
#         return self.__name
#
#     def get_symbol(self):
#
#         return self.__symbol
#
#     def get_number(self):
#
#         return self.__number
#
# element_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
#
# hydrogen = Element(**element_dict)
#
# print(hydrogen.get_name())
#
# print(hydrogen.get_symbol())
#
# print(hydrogen.get_number())
#
#
# This will output:
#
#
# Hydrogen
#
# H
#
# 1

# %% [markdown]
# ## 9. Define three classes: Bear, Rabbit, and Octothorpe. For each, define only one method: eats(). This should return 'berries' (Bear), 'clover' (Rabbit), or 'campers' (Octothorpe). Create one object from each and print what it eats.
#
#
# Ans:-Here's an implementation of the three classes Bear, Rabbit, and Octothorpe, each with a single method eats() that returns a different food item:
#
# class Bear:
#
#     def eats(self):
#
#         return 'berries'
#
# class Rabbit:
#
#     def eats(self):
#
#         return 'clover'
#
# class Octothorpe:
#
#     def eats(self):
#
#         return 'campers'
#
# bear = Bear()
#
# print('Bear eats', bear.eats())
#
# rabbit = Rabbit()
#
# print('Rabbit eats', rabbit.eats())
#
# octothorpe = Octothorpe()
#
# print('Octothorpe eats', octothorpe.eats())
#
#
# The code will output:
#
# Bear eats berries
#
# Rabbit eats clover
#
# Octothorpe eats campers

# %% [markdown]
# ## 10. Define these classes: Laser, Claw, and SmartPhone. Each has only one method: does(). This returns 'disintegrate' (Laser), 'crush' (Claw), or 'ring' (SmartPhone). Then, define the class Robot that has one instance (object) of each of these. Define a does() method for the Robot that prints what its component objects do.
#
# Ans:-Here's an implementation of the classes Laser, Claw, SmartPhone, and Robot, with Laser, Claw, and SmartPhone each having a single method does() that returns a different action, and Robot having an instance of each of these components and a does() method that calls the does() method on each component and prints their actions:
#
# class Laser:
#
#     def does(self):
#
#         return 'disintegrate'
#
# class Claw:
#
#     def does(self):
#
#         return 'crush'
#
# class SmartPhone:
#
#     def does(self):
#
#         return 'ring'
#
# class Robot:
#
#     def __init__(self):
#
#         self.laser = Laser()
#
#         self.claw = Claw()
#
#         self.phone = SmartPhone()
#
#     def does(self):
#
#         print('Laser:', self.laser.does())
#
#         print('Claw:', self.claw.does())
#
#         print('SmartPhone:', self.phone.does())
#
# robot = Robot()
#
# robot.does()
#
#
# The code will output:
#
# Laser: disintegrate
#
# Claw: crush
#
# SmartPhone: ring
